# %%
def solution(seoul):
    answer = "김서방은 {}에 있다".format(seoul.index("Kim"))
    return answer

seoul = ["Jane", "Kim", "Kim"]
solution(seoul)
# Out:
# '김서방은 1에 있다'

# %%
def solution(seoul):
    kim = seoul.index("Kim")
    answer = f"김서방은 { seoul.index("Kim") } 에 있다"
    return answer

seoul = ["Jane", "Kim", "Kim"]
solution(seoul)
# Out:
#   File "<ipython-input-5-3f8a3aea97f7>", line 3
#     answer = f"김서방은 { seoul.index("Kim") } 에 있다"
#                                      ^
# SyntaxError: invalid syntax

# %%
def solution(seoul):
    kim = seoul.index("Kim")
    answer = f"김서방은 {kim} 에 있다"
    return answer

seoul = ["Jane", "Kim"]
solution(seoul)
# Out:
# '김서방은 1 에 있다'

# %%
def solution(seoul):
    return ('김서방은 %d 에 있다' %(seoul.index('Kim')))

seoul = ["Jane", "Kim"]
solution(seoul)
# Out:
# '김서방은 1 에 있다'

# %%
def solution(seoul):
    return ('김서방은 %d %d 에 있다' %(seoul.index('Kim'),seoul.index('Kim')))

seoul = ["Jane", "Kim"]
solution(seoul)
# Out:
# '김서방은 1 1 에 있다'
