# %%
def solution(word):
    words = ['A', 'E', 'I', 'O', 'U']
    _list =[]
    for idx, word_i in enumerate(words):
        _list += [i*word_i for i in range(1,6) ]
        for _list_i in range(4,2,-1):
            for i in range(1,5):
                _list.append(word_i * _list_i + words[i]) 

    
    answer = _list.index(word) +1
    return answer

word ="AAAAE"
solution(word)
# Out:
# 6

# %%
def solution(word):
    words = ['A', 'E', 'I', 'O', 'U']
    _list =[]
    for idx, word_i in enumerate(words):
        _list += [i*word_i for i in range(1,6) ]
        for _list_i in range(4,2,-1):
            for i in range(1,5):
                _list.append(word_i * _list_i + words[i]) 

    
    answer = _list.index(word) +1
    return answer

word ="AAAE"
solution(word)
# Out:
# 10

# %%
def solution(word):
    words = ['A', 'E', 'I', 'O', 'U']
    _list =[]
    cnt = 0
    for idx, word_i in enumerate(words):
        _list += [i*word_i for i in range(1,6)]
        
        for i in range(4,0,-1):
            for j in words:
                if j != words[cnt]:
                    _list.append(words[cnt] * i + j)


        

    print(_list)
    
    answer= 0
    answer = _list.index(word) +1
    return answer

word ="AAAE"
solution(word)
# Out:
# ['A', 'AA', 'AAA', 'AAAA', 'AAAAA', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAE', 'AAI', 'AAO', 'AAU', 'AE', 'AI', 'AO', 'AU', 'E', 'EE', 'EEE', 'EEEE', 'EEEEE', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAE', 'AAI', 'AAO', 'AAU', 'AE', 'AI', 'AO', 'AU', 'I', 'II', 'III', 'IIII', 'IIIII', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAE', 'AAI', 'AAO', 'AAU', 'AE', 'AI', 'AO', 'AU', 'O', 'OO', 'OOO', 'OOOO', 'OOOOO', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAE', 'AAI', 'AAO', 'AAU', 'AE', 'AI', 'AO', 'AU', 'U', 'UU', 'UUU', 'UUUU', 'UUUUU', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAE', 'AAI', 'AAO', 'AAU', 'AE', 'AI', 'AO', 'AU']
# 10

# %%
def solution(word):
    words = ['A', 'E', 'I', 'O', 'U']
    _list =[]
    cnt = 0
    for idx, word_i in enumerate(words):
        _list += [i*word_i for i in range(1,5)]
        start_list = _list[::]
        for i in range(len(start_list)-1,0,-1):
            for j in words:
                _list.append(start_list[i] + j)
        

    print(_list)
    
    answer= 0
    answer = _list.index(word) +1
    return answer

word ="AAAEA"
solution(word)
# Out:
# ['A', 'AA', 'AAA', 'AAAA', 'AAAAA', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAA', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAA', 'AAE', 'AAI', 'AAO', 'AAU', 'E', 'EE', 'EEE', 'EEEE', 'EEEEA', 'EEEEE', 'EEEEI', 'EEEEO', 'EEEEU', 'EEEA', 'EEEE', 'EEEI', 'EEEO', 'EEEU', 'EEA', 'EEE', 'EEI', 'EEO', 'EEU', 'EA', 'EE', 'EI', 'EO', 'EU', 'AAUA', 'AAUE', 'AAUI', 'AAUO', 'AAUU', 'AAOA', 'AAOE', 'AAOI', 'AAOO', 'AAOU', 'AAIA', 'AAIE', 'AAII', 'AAIO', 'AAIU', 'AAEA', 'AAEE', 'AAEI', 'AAEO', 'AAEU', 'AAAA', 'AAAE', 'AAAI', 'AAAO', 'AAAU', 'AAAUA', 'AAAUE', 'AAAUI', 'AAAUO', 'AAAUU', 'AAAOA', 'AAAOE', 'AAAOI', 'AAAOO', 'AAAOU', 'AAAIA', 'AAAIE', 'AAAII', 'AAAIO', 'AAAIU', 'AAAEA', 'AAAEE', 'AAAEI', 'AAAEO', 'AAAEU', 'AAAAA', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAAUA', 'AAAAUE', 'AAAAUI', 'AAAAUO', 'AAAAUU', 'AAAAOA', 'AAAAOE', 'AAAAOI', 'AAAAOO', 'AAAAOU', 'AAAAIA', 'AAAAIE', 'AAAAII', 'AAAAIO', 'AAAAIU', 'AAAAEA', 'AAAAEE', 'AAAAEI', 'AAAAEO', 'AAAAEU', 'AAAAAA', 'AAAAAE', 'AAAAAI', 'AAAAAO', 'AAAAAU', 
# ...

# %%
words = ['A', 'E', 'I', 'O', 'U']
words_ = []

def word_create(level, word_):
    words_.append(word_)
    [word_create(level+1 , word_ + words[i]) for i in range(0,len(words)) if level <len(words)]
    
    
def solution(word):
    word_create(0, '')
    answer = words_.index(word)
    return answer

word ="AE"
solution(word)
# Out:
# 158

# %%
words = ['A', 'E']
words_ = []

def word_create(level, word_):
    words_.append(word_)
    for i in range(len(words)):
         if level < len(words):
            print(i, "===",level,"====", word_ ,"==",words[i] ,word_ + words[i])
            word_create(level+1 , word_ + words[i])
    
    
def solution(word):
    word_create(0, '')
    answer = words_.index(word)
    return answer

word ="AE"
solution(word)
# Out:
# 0 === 0 ====  == A A
# 0 === 1 ==== A == A AA
# 1 === 1 ==== A == E AE
# 1 === 0 ====  == E E
# 0 === 1 ==== E == A EA
# 1 === 1 ==== E == E EE
# 3

# %%
words = ['A', 'E', 'I']
words_ = []
def word_create(level, word_):
    words_.append(word_)
    print(level,"====", word_ )
    [word_create(level+1 , word_ + words[i]) for i in range(0,3) if level <3]
    
    
def solution(word):
    word_create(0, '')
    answer = words_.index(word)
    return answer

word ="AEI"
solution(word)
# Out:
# 0 ====
# 1 ==== A
# 2 ==== AA
# 3 ==== AAA
# 3 ==== AAE
# 3 ==== AAI
# 2 ==== AE
# 3 ==== AEA
# 3 ==== AEE
# 3 ==== AEI
# 2 ==== AI
# 3 ==== AIA
# 3 ==== AIE
# 3 ==== AII
# 1 ==== E
# 2 ==== EA
# 3 ==== EAA
# 3 ==== EAE
# 3 ==== EAI
# 2 ==== EE
# 3 ==== EEA
# 3 ==== EEE
# 3 ==== EEI
# 2 ==== EI
# 3 ==== EIA
# 3 ==== EIE
# 3 ==== EII
# 1 ==== I
# 2 ==== IA
# 3 ==== IAA
# 3 ==== IAE
# 3 ==== IAI
# 2 ==== IE
# 3 ==== IEA
# 3 ==== IEE
# 3 ==== IEI
# 2 ==== II
# 3 ==== IIA
# 3 ==== IIE
# 3 ==== III
# 9

# %%
vowels = ['A', 'E', 'I', 'O', 'U']
words = []

def create_words(lev, s):
    words.append(s)
    for i in range(0, 5):
        if lev < 5:
            create_words(lev + 1, s+vowels[i])
            

def solution(word):
    answer = 0
    create_words(0, '')
    print(words)
    words_n = len(words)
    for i in range(words_n):
        if word == words[i]:
            answer = i
            break
    return answer

word ="AAAEA"
solution(word)
# Out:
# ['', 'A', 'AA', 'AAA', 'AAAA', 'AAAAA', 'AAAAE', 'AAAAI', 'AAAAO', 'AAAAU', 'AAAE', 'AAAEA', 'AAAEE', 'AAAEI', 'AAAEO', 'AAAEU', 'AAAI', 'AAAIA', 'AAAIE', 'AAAII', 'AAAIO', 'AAAIU', 'AAAO', 'AAAOA', 'AAAOE', 'AAAOI', 'AAAOO', 'AAAOU', 'AAAU', 'AAAUA', 'AAAUE', 'AAAUI', 'AAAUO', 'AAAUU', 'AAE', 'AAEA', 'AAEAA', 'AAEAE', 'AAEAI', 'AAEAO', 'AAEAU', 'AAEE', 'AAEEA', 'AAEEE', 'AAEEI', 'AAEEO', 'AAEEU', 'AAEI', 'AAEIA', 'AAEIE', 'AAEII', 'AAEIO', 'AAEIU', 'AAEO', 'AAEOA', 'AAEOE', 'AAEOI', 'AAEOO', 'AAEOU', 'AAEU', 'AAEUA', 'AAEUE', 'AAEUI', 'AAEUO', 'AAEUU', 'AAI', 'AAIA', 'AAIAA', 'AAIAE', 'AAIAI', 'AAIAO', 'AAIAU', 'AAIE', 'AAIEA', 'AAIEE', 'AAIEI', 'AAIEO', 'AAIEU', 'AAII', 'AAIIA', 'AAIIE', 'AAIII', 'AAIIO', 'AAIIU', 'AAIO', 'AAIOA', 'AAIOE', 'AAIOI', 'AAIOO', 'AAIOU', 'AAIU', 'AAIUA', 'AAIUE', 'AAIUI', 'AAIUO', 'AAIUU', 'AAO', 'AAOA', 'AAOAA', 'AAOAE', 'AAOAI', 'AAOAO', 'AAOAU', 'AAOE', 'AAOEA', 'AAOEE', 'AAOEI', 'AAOEO', 'AAOEU', 'AAOI', 'AAOIA', 'AAOIE', 'AAOII', 'AAOIO', 'AAOIU', 
# ...

# %%
from itertools import permutations


def solution(word):
    return sorted(sum([list(set(permutations("AEIOU" * 5, i))) for i in range(1, 6)], [])).index(tuple(word)) + 1

# %% [markdown]
# 다른 사람 풀이

# %%
from itertools import product
def solution(word):
    answer = 0
    a = ["".join(list(j)) for i in range(1, 6) for j in product(["A", "E", "I", "O", "U"], repeat=i)]    
    a.sort()
    return a.index(word)+1

# %%
for i in range(1, 6) :
    for j in product(["A", "E", "I", "O", "U"], repeat=i):
        print(j)
# Out:
# ('A',)
# ('E',)
# ('I',)
# ('O',)
# ('U',)
# ('A', 'A')
# ('A', 'E')
# ('A', 'I')
# ('A', 'O')
# ('A', 'U')
# ('E', 'A')
# ('E', 'E')
# ('E', 'I')
# ('E', 'O')
# ('E', 'U')
# ('I', 'A')
# ('I', 'E')
# ('I', 'I')
# ('I', 'O')
# ('I', 'U')
# ('O', 'A')
# ('O', 'E')
# ('O', 'I')
# ('O', 'O')
# ('O', 'U')
# ('U', 'A')
# ('U', 'E')
# ('U', 'I')
# ('U', 'O')
# ('U', 'U')
# ('A', 'A', 'A')
# ('A', 'A', 'E')
# ('A', 'A', 'I')
# ('A', 'A', 'O')
# ('A', 'A', 'U')
# ('A', 'E', 'A')
# ('A', 'E', 'E')
# ('A', 'E', 'I')
# ('A', 'E', 'O')
# ('A', 'E', 'U')
# ('A', 'I', 'A')
# ('A', 'I', 'E')
# ('A', 'I', 'I')
# ('A', 'I', 'O')
# ('A', 'I', 'U')
# ('A', 'O', 'A')
# ('A', 'O', 'E')
# ('A', 'O', 'I')
# ('A', 'O', 'O')
# ('A', 'O', 'U')
# ('A', 'U', 'A')
# ('A', 'U', 'E')
# ('A', 'U', 'I')
# ('A', 'U', 'O')
# ('A', 'U', 'U')
# ('E', 'A', 'A')
# ('E', 'A', 'E')
# ('E', 'A', 'I')
# ('E', 'A', 'O')
# ('E', 'A', 'U')
# ('E', 'E', 'A')
# ('E', 'E', 'E')
# ('E', 'E', 'I')
# ('E', 'E', 'O')
# ('E', 'E', 'U')
# ...
